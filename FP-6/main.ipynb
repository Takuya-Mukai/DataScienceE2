# %%
import machine

# %%
rmse_train, rmse_test, depths = machine.compare()
machine.gap(rmse_train, rmse_test, depths)

# %% [markdown]
# ## result
# + As the tree depth increases, the training RMSE decreases monotonically.
# + In contrast, the validation RMSE is minimized at a moderate tree depth (around 5–10), indicating a trade-off between underfitting at low depths and overfitting at high depths.
